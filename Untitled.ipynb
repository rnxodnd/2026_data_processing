# %%
a = 1
b = 2
c = 3
d = 4

# %%
a+b, a-b, a*c
# Out:
# (3, -1, 3)

# %%
a = input()
print(a)
type(a)
# Out:
#  10
# 10
# str

# %%
#정수형 : 소수점으로 표현하지 않는 수. python에서 int
a = 123
b = -123
c = 0
type(a)
# Out:
# int

# %%
#실수형 : 소수점으로 표현해야 하는 수 python에서 float
a = 1.2
b = -2.1
type(b)
# Out:
# float

# %%
#논리형 : True, False의 값을 갖는 자료형. 비교연산자, 논리연산자의 결과값으로 반환
10<15
10<=5
10>61
# Out:
# False

# %%
#python에서 =는 변수선언에서 사용하는 대입기호임. 같다는 조건식을 나타낼 때에는 '=='를 사용
a = 0
1 == 0
# Out:
# False

# %%
#문자형 : 큰따옴표 또는 작은따옴표 안에 문자를 넣어 사용. 
a = "Life is too short, You need python"
a
# Out:
# 'Life is too short, You need python'

# %%
#스칼라 : 일반적으로 하나의 값만 가지는 단일 데이터. 정수, 실수, 문자, 문자열, 불리언 등이 이에 해당하며
#리스트, 튜플, 딕셔너리, 집합처럼 여러 값을 담는 자료형은 보통 스칼라가 아님
#스칼라는 가장 간단한 형태의 데이터로, 하위 구조가 없는 단일 데이터 단위를 나타냄
A = 10

# %%
#선형구조 - 리스트 : 데이터의 유형상관 없이 저장하고, 저장된 데이터들을 그룹화 할 수 있는 데이터 구조
#숫자, 문자, 논리값 등등 다양한 데이터 유형의 요소가 포함될 수 있음.

#리스트명 = [요소1, 요소2 ... ]
list1 = ['독고영재, 50', '김철수, 30']
list1
# Out:
# ['독고영재, 50', '김철수, 30']

# %%
#리스트는 문자와 같이 각각의 공간을 가진다. 
#요소1 = 0번째 
list1[0]
# Out:
# '독고영재, 50'

# %%
#벡터 : 값을 저장하고 조작할 수 있는 기본 데이터 구조
#숫자, 문자, 또는 논리 값과 같은 동일한 데이터 유형의 요소를 보유할 수 있는 1차원 배열

# %%
#Array(배열) : 단일 타입으로 구성되는 자료구조
import numpy as np
a = np.array([1,2,3])
b = np.array([5,6,7])
c = a+b #각 요소의 값이 계산되어 짐.
type(c) #array
# Out:
# numpy.ndarray

# %%
#2차원 배열
import numpy as np
a = np.array([[1,2,3],[4,5,6]])
b = np.array([[5,6,7],[8,9,10]])
c = a+b #각 요소의 값이 계산되어 짐.
#해당 방법을 사용하여 n차원까지 배열을 확장할 수 있음.
# Out:
# array([[ 6,  8, 10],
#        [12, 14, 16]])

# %%
#문자열 인덱싱 : 연속적인 객체들에 범위를 지정해 선택하여 객체들을 가져오는 방법 및 표기법
A = "안녕하세요"
A[0:2] #0부터 시작해서 n번째 전까지
A[-1:] #뒤에서부터 출력
# Out:
# '안녕'

# %%
#문자열 format :문자열 중간중간 특정 변수의 값을 넣어주기 위해 사용
#format()
A = 'I am a {}'
B = 'boy'
A.format(B)
# Out:
# 'I am a boy'

# %%
#format은 단순 문자열에도 사용됨
print(("{:.2f}, {:.3f}").format(3.1415, 3.1415))
# Out:
# 3.14, 3.142

# %%
#replace: 특정 문자열을 찾아 다른 문자열로 대체
#변수.replace("기존의 문자", "변환하고 싶은 문자")
url = "http://www.youtube.com/"
str = url.replace("https://","")
str
# Out:
# 'http://www.youtube.com/'

# %%
#list는 다양한 타입을 인자로 가질 수 있음
#리스트 추가하기
a = ["hi", 10, "80", "김철수", 50, 50.6]
#리스트명.append(추가할 값)
a.append(1)
a
# Out:
# ['hi', 10, '80', '김철수', 50, 50.6, 1]

# %%
#list 인자 삭제
#리스트명.pop(제거할 값의 위치)
a.pop(1)
a
# Out:
# ['hi', '80', '김철수', 50, 50.6, 1]

# %%
#배열에 값 추가
a = np.array([1,2,3,4])
a = np.append(a,[4,5])
a
# Out:
# array([1, 2, 3, 4, 4, 5])

# %%
#위치를 지정하여 추가
a = np.insert(a,1,[7,8])
a
# Out:
# array([1, 7, 8, 7, 8, 2, 3, 4, 4, 5])

# %%
#배열 수직으로 합치기
array1 = np.array([[1,2],[3,4]])
array2 = np.array([[5,6],[7,8]])
merged_array = np.vstack((array1, array2))
merged_array
# Out:
# array([[1, 2],
#        [3, 4],
#        [5, 6],
#        [7, 8]])

# %%
#배열 수평으로 합치기
merged_array = np.hstack((array1, array2))
merged_array
# Out:
# array([[1, 2, 5, 6],
#        [3, 4, 7, 8]])

# %%
#딕셔너리: 키-값으로 쌍을 저장하는 효율적인 자료구조로 빠른 데이터 조회, 수정, 삭제 가능
#키값은 중복이 불가능하며 하나의 키 값을 정해 변수를 넣어주는 방법
#A = {키값: 변수값, 키값:변수값}
A = {1:"김철수", 20: "박영희"}
A
#딕셔너리의 키 값을 설정하는 것에 있어 꼭 수치값이 아니라도 괜찮음
# Out:
# {1: '김철수', 20: '박영희'}

# %%
#딕셔너리 추가 
A = {"1-A": "김철수", "20-B": "박영희"}
A["2-A"] = "영희"
A
# Out:
# {'1-A': '김철수', '20-B': '박영희', '2-A': '영희'}

# %%
#딕셔너리 삭제
del A["20-B"]
A
# Out:
# {'1-A': '김철수', '2-A': '영희'}

# %%
#데이터프레임: 프로그래밍 및 데이터 분석에 일반적으로 사용되는 표 형식의 데이터 구조
#행과 열로 구성된 다양한 형태를 가지고 있는 리스트의 집
import pandas as pd

data = {
    'Name': ['Alice', 'Bob', 'Charlie'],
    'Age': [25, 30, 35],
    'City': ['New York', 'Paris', 'London']
}

df = pd.DataFrame(data)
df
#각 데이터의 길이가 같아야 생성 가능
# Out:
#       Name  Age      City
# 0    Alice   25  New York
# 1      Bob   30     Paris
# 2  Charlie   35    London

# %%
#Text파일은 데이터를 저장하고 표현하기 위해 간단하고 널리 사용되는 형식으로,
#일반적으로 각 데이터 포인트가 구분기호로 구분된 일반 텍스트로 저장됨.
#단순성과 다양한 프로그래밍 언어 및 소프트웨어 응용 프로그램과의 호환성이 좋지만,
#복잡한 데이터 구조에 대한 지원이 부족하고 데이터 조작 및 분석 기능이 제한됨.

# %%
#EXCEL 파일은 스프레드시트 파일로 데이터 구성, 조작, 시각화 및 분석을 위한 포괄적인 기능 세트를 제공함.
#복잡한 수식, 조건부 서식, 그래픽 표현 및 다양한 데이터 유형을 지원함
#사용자 친화적인 인터페이스와 광범위한 기능을 제공하여 기본 및 고급 데이터 관리 작업에 모두 적합함.
#크기가 상대적으로 크고 타사 소프트웨어와의 호환성 문제가 발생할 수 있음

# %%
#CSV파일은 테이블 형식 데이터 저장 및 교환에 일반적으로 사용되는 특정 유형의 텍스트 파일 형식
#CSV 파일에서각행은 데이터레코드를 나타내며 행 내의 각 필드는 쉼표 또는 기타 지정된 구분기호로 구분됨
#CSV 파일은 스프레드시트 소프트웨어 및 데이터베이스 응용 프로그램에서 광범위하게 지원되므로 
#데이터 공유 및 상호 운용성을 위해 많이 사용 가능함
#복잡한 데이터 구조 또는 수식에 대한 지원이 제한됌.
